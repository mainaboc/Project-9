# %% [markdown]
# # Project 9 Chetima:

# %%
#importing the necessary packages.
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# sources:
#
# http://localhost:8888/notebooks/CS%20215/Individual%20Projects%20Chetima
#
# https://stackoverflow.com/questions/12850345/how-do-i-combine-two-dataframes

# %% [markdown]
# Questions:
# 1. Is there any corelation between the Human Development Index and the Mental Health disorder rate ?

# %%
df1 = pd.read_csv("human-development-index.csv")
df2 = pd.read_csv("share-with-mental-and-substance-disorders.csv")

# %%
df1.tail()
# Out:
#         Entity Code  Year  Human Development Index
# 5918  Zimbabwe  ZWE  2017                    0.594
# 5919  Zimbabwe  ZWE  2018                    0.602
# 5920  Zimbabwe  ZWE  2019                    0.601
# 5921  Zimbabwe  ZWE  2020                    0.600
# 5922  Zimbabwe  ZWE  2021                    0.593

# %%
#Selecting a particular year of study.
df_HDI_2019 = df1[df1.Year == 2019]

# %%
df_HDI_2019
# Out:
#            Entity      Code  Year  Human Development Index
# 29    Afghanistan       AFG  2019                    0.488
# 61        Albania       ALB  2019                    0.810
# 93        Algeria       DZA  2019                    0.748
# 115       Andorra       AND  2019                    0.873
# 138        Angola       AGO  2019                    0.595
# ...           ...       ...   ...                      ...
# 5792      Vietnam       VNM  2019                    0.703
# 5824        World  OWID_WRL  2019                    0.739
# 5856        Yemen       YEM  2019                    0.461
# 5888       Zambia       ZMB  2019                    0.575
# 5920     Zimbabwe       ZWE  2019                    0.601
#
# [202 rows x 4 columns]

# %%
df1_2 = df_HDI_2019.sort_values("Human Development Index", ascending = False)

# %%
df1_2.head(13)
# Out:
#              Entity Code  Year  Human Development Index
# 5108    Switzerland  CHE  2019                    0.962
# 3956         Norway  NOR  2019                    0.961
# 2380        Iceland  ISL  2019                    0.960
# 2316      Hong Kong  HKG  2019                    0.952
# 1991        Germany  DEU  2019                    0.948
# 5076         Sweden  SWE  2019                    0.947
# 1408        Denmark  DNK  2019                    0.946
# 4708      Singapore  SGP  2019                    0.943
# 3782    Netherlands  NLD  2019                    0.943
# 2540        Ireland  IRL  2019                    0.942
# 281       Australia  AUS  2019                    0.941
# 3072  Liechtenstein  LIE  2019                    0.940
# 1841        Finland  FIN  2019                    0.939

# %%
df1_2.tail(10)
# Out:
#                         Entity Code  Year  Human Development Index
# 2139                    Guinea  GIN  2019                    0.467
# 5856                     Yemen  YEM  2019                    0.461
# 3654                Mozambique  MOZ  2019                    0.456
# 803               Burkina Faso  BFA  2019                    0.452
# 3314                      Mali  MLI  2019                    0.433
# 835                    Burundi  BDI  2019                    0.431
# 985   Central African Republic  CAF  2019                    0.411
# 3878                     Niger  NER  2019                    0.406
# 1007                      Chad  TCD  2019                    0.403
# 4898               South Sudan  SSD  2019                    0.393

# %%
#A new dataframe for the 10 highest HDIs
max_HDI = df1_2[df1_2["Human Development Index"] >= 0.942]

# %%
#A new dataframe for the 10 lowest HDIs
min_HDI = df1_2[df1_2["Human Development Index"] <= 0.467]

# %%
max_HDI
# Out:
#            Entity Code  Year  Human Development Index
# 5108  Switzerland  CHE  2019                    0.962
# 3956       Norway  NOR  2019                    0.961
# 2380      Iceland  ISL  2019                    0.960
# 2316    Hong Kong  HKG  2019                    0.952
# 1991      Germany  DEU  2019                    0.948
# 5076       Sweden  SWE  2019                    0.947
# 1408      Denmark  DNK  2019                    0.946
# 4708    Singapore  SGP  2019                    0.943
# 3782  Netherlands  NLD  2019                    0.943
# 2540      Ireland  IRL  2019                    0.942

# %%
#Merge the two
df_merged1 = max_HDI.append(min_HDI, ignore_index=True)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_9104\3332806332.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merged1 = max_HDI.append(min_HDI, ignore_index=True)

# %%
min_HDI
# Out:
#                         Entity Code  Year  Human Development Index
# 2139                    Guinea  GIN  2019                    0.467
# 5856                     Yemen  YEM  2019                    0.461
# 3654                Mozambique  MOZ  2019                    0.456
# 803               Burkina Faso  BFA  2019                    0.452
# 3314                      Mali  MLI  2019                    0.433
# 835                    Burundi  BDI  2019                    0.431
# 985   Central African Republic  CAF  2019                    0.411
# 3878                     Niger  NER  2019                    0.406
# 1007                      Chad  TCD  2019                    0.403
# 4898               South Sudan  SSD  2019                    0.393

# %%
df_merged1
# Out:
#                       Entity Code  Year  Human Development Index
# 0                Switzerland  CHE  2019                    0.962
# 1                     Norway  NOR  2019                    0.961
# 2                    Iceland  ISL  2019                    0.960
# 3                  Hong Kong  HKG  2019                    0.952
# 4                    Germany  DEU  2019                    0.948
# 5                     Sweden  SWE  2019                    0.947
# 6                    Denmark  DNK  2019                    0.946
# 7                  Singapore  SGP  2019                    0.943
# 8                Netherlands  NLD  2019                    0.943
# 9                    Ireland  IRL  2019                    0.942
# 10                    Guinea  GIN  2019                    0.467
# 11                     Yemen  YEM  2019                    0.461
# 12                Mozambique  MOZ  2019                    0.456
# ...

# %%
#Selecting a year of study
df_mental_2019 = df2[df2.Year == 2019]

# %%
df_mental_2019.head()
# Out:
#                    Entity Code  Year  \
# 29            Afghanistan  AFG  2019
# 59   African Region (WHO)  NaN  2019
# 89                Albania  ALB  2019
# 119               Algeria  DZA  2019
# 149        American Samoa  ASM  2019
#
#      Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)
# 29                                               17.12
# 59                                               12.21
# 89                                               11.56
# 119                                              14.78
# 149                                              11.24

# %%
df2_2 = df_mental_2019.sort_values("Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)", ascending = False)

# %%
#New dataframe without the total data for the world
df2_3 = df2_2[df2_2.Entity != "World"]

# %%
df2_3.head(10)
# Out:
#            Entity Code  Year  \
# 329     Australia  AUS  2019
# 4051  New Zealand  NZL  2019
# 2701         Iran  IRN  2019
# 4711     Portugal  PRT  2019
# 5521        Spain  ESP  2019
# 4501    Palestine  PSE  2019
# 2761      Ireland  IRL  2019
# 2311    Greenland  GRL  2019
# 29    Afghanistan  AFG  2019
# 5701  Switzerland  CHE  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)
# 329                                               19.35
# 4051                                              19.04
# 2701                                              18.89
# 4711                                              18.45
# 5521                                              18.32
# 4501                                              18.14
# 2761                                              17.61
# 2311                                              17.54
# 29                                                17.12
# ...

# %%
#Merged worldwide HDIs with their respected proportion of mental health disorders.
df_merged = df_HDI_2019.merge(df_mental_2019)

# %%
#Noticed that I did not have data for Singapore and Homgkong, so I had to change with the next best 2 HDIs and ajust for the percentage of mental health disorder.
mental =  df2_2[(df2_2["Entity"]=="Switzerland") | (df2_2["Entity"] == "Norway")| (df2_2['Entity'] =="Iceland" )| (df2_2["Entity"] == "Australia") |(df2_2["Entity"] == "Germany" ) | (df2_2["Entity"] == "Sweden") | (df2_2["Entity"] == "Denmark") |(df2_2["Entity"] == "Finland") |(df2_2["Entity"] == "Netherlands") |(df2_2["Entity"] == "Ireland") |(df2_2["Entity"] == "Guinea") |(df2_2["Entity"] == "Yemen") |(df2_2["Entity"] == "Mozambique") |(df2_2["Entity"] == "Burkina Faso") |(df2_2["Entity"] == "Mali") |(df2_2["Entity"] == "Burundi") |(df2_2["Entity"] == "Central African Republic") |(df2_2["Entity"] == "Niger") |(df2_2["Entity"] == "Chad") |(df2_2["Entity"] == "South Sudan")]

# %%
mental
# Out:
#                         Entity Code  Year  \
# 329                  Australia  AUS  2019
# 2761                   Ireland  IRL  2019
# 5701               Switzerland  CHE  2019
# 4021               Netherlands  NLD  2019
# 6691                     Yemen  YEM  2019
# 4351                    Norway  NOR  2019
# 5671                    Sweden  SWE  2019
# 2221                   Germany  DEU  2019
# 2041                   Finland  FIN  2019
# 1079  Central African Republic  CAF  2019
# 2611                   Iceland  ISL  2019
# 1501                   Denmark  DNK  2019
# 3871                Mozambique  MOZ  2019
# 5461               South Sudan  SSD  2019
# 929                    Burundi  BDI  2019
# 1109                      Chad  TCD  2019
# 2431                    Guinea  GIN  2019
# 899               Burkina Faso  BFA  2019
# 4111                     Niger  NER  2019
# 3481                      Mali  MLI  2019
#
# ...

# %%
#I had to arrange for the first merged dataframe too.
df_merge1_1 = df1_2[(df1_2["Entity"]=="Switzerland") | (df1_2["Entity"] == "Norway")| (df1_2['Entity'] =="Iceland" )| (df1_2["Entity"] == "Australia") |(df1_2["Entity"] == "Germany" ) | (df1_2["Entity"] == "Sweden") | (df1_2["Entity"] == "Denmark") |(df1_2["Entity"] == "Finland") |(df1_2["Entity"] == "Netherlands") |(df1_2["Entity"] == "Ireland") |(df1_2["Entity"] == "Guinea") |(df1_2["Entity"] == "Yemen") |(df1_2["Entity"] == "Mozambique") |(df1_2["Entity"] == "Burkina Faso") |(df1_2["Entity"] == "Mali") |(df1_2["Entity"] == "Burundi") |(df1_2["Entity"] == "Central African Republic") |(df1_2["Entity"] == "Niger") |(df1_2["Entity"] == "Chad") |(df1_2["Entity"] == "South Sudan")]

# %%
#Merging the 10 highest and lowest HDIs with heir respective proportion of mental health disorders.
df_merged2 = df_merge1_1.merge(mental, on="Entity")

# %%
df_merged2
# Out:
#                       Entity Code_x  Year_x  Human Development Index Code_y  \
# 0                Switzerland    CHE    2019                    0.962    CHE
# 1                     Norway    NOR    2019                    0.961    NOR
# 2                    Iceland    ISL    2019                    0.960    ISL
# 3                    Germany    DEU    2019                    0.948    DEU
# 4                     Sweden    SWE    2019                    0.947    SWE
# 5                    Denmark    DNK    2019                    0.946    DNK
# 6                Netherlands    NLD    2019                    0.943    NLD
# 7                    Ireland    IRL    2019                    0.942    IRL
# 8                  Australia    AUS    2019                    0.941    AUS
# 9                    Finland    FIN    2019                    0.939    FIN
# 10                    Guinea    GIN    2019                    0.467    GIN
# ...

# %%
#Creating a new dataframe in order to plot without extreme outliers. 
df_scatter = df_merged[df_merged.Entity != "World"]

# %%
#Ploting a scatterplot to determine a correlation.
plt.scatter(df_scatter["Human Development Index"], df_scatter["Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)"])
plt.xlabel("Human Development Index")
plt.ylabel("% of population with mental health disorders")
plt.title("Worldwide")
# Out:
# Text(0.5, 1.0, 'Worldwide')

# %%
#Scatterplot for the 10 lowest and highest HDIs in order to better determine a correlation.
plt.scatter(df_merged2["Human Development Index"], df_merged2["Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)"])
plt.xlabel("Human Development index")
plt.ylabel("% population with mental health disorders")
plt.title("10 lowest and 10 highest HDI countries")
# Out:
# Text(0.5, 1.0, '10 lowest and 10 highest HDI countries')

# %%
#Seaborn
sns.scatterplot( x = df_merged2["Human Development Index"], y =  df_merged2["Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)"])
# Out:
# <AxesSubplot:xlabel='Human Development Index', ylabel='Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)'>
